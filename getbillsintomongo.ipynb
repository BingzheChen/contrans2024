# %%
from contrans import contrans
import numpy as np
import pandas as pd
import dotenv
import json
import os
import requests
import psycopg
import sqlite3
from sqlalchemy import create_engine

dotenv.load_dotenv()

comgresskey = os.getenv('congresskey')
postgres_password = os.getenv('POSTGRES_PASSWORD')

# %%
ct = contrans()

# %%
mongo_bills = ct.connect_to_mongo(from_scratch=True)

# %%
bioguideIDs = ct.get_bioguideIDs()
members = bioguideIDs['bioguideId']
members
# Out:
# 0      G000578
# 1      L000605
# 2      W000829
# 3      N000188
# 4      Y000064
#         ...
# 549    H001038
# 550    S001222
# 551    S001192
# 552    F000062
# 553    S001197
# Name: bioguideId, Length: 554, dtype: object

# %%
ct.upload_many_members_to_mongo(mongo_bills, members)
# Out:
# Now uploading bills from G000578 to MongoDB: legislators 1 of 554
# Now uploading bills from L000605 to MongoDB: legislators 2 of 554
# Failed to upload L000605 to MongoDB
# Now uploading bills from W000829 to MongoDB: legislators 3 of 554
# Failed to upload W000829 to MongoDB
# Now uploading bills from N000188 to MongoDB: legislators 4 of 554
# Now uploading bills from Y000064 to MongoDB: legislators 5 of 554
# Now uploading bills from W000802 to MongoDB: legislators 6 of 554
# Now uploading bills from W000800 to MongoDB: legislators 7 of 554
# Failed to upload W000800 to MongoDB
# Now uploading bills from W000779 to MongoDB: legislators 8 of 554
# Now uploading bills from W000437 to MongoDB: legislators 9 of 554
# Now uploading bills from V000137 to MongoDB: legislators 10 of 554
# Now uploading bills from W000790 to MongoDB: legislators 11 of 554
# Now uploading bills from T000278 to MongoDB: legislators 12 of 554
# Now uploading bills from W000817 to MongoDB: legislators 13 of 554
# Failed to upload W000817 to MongoDB
# Now uploading bills from W000805 to MongoDB: legislators 14 of 554
# Now uploading bills from V000128 to MongoDB: legislators 15 of 554
# Now uploading bills from T000476 to MongoDB: legislators 16 of 554
# Failed to upload T000476 to MongoDB
# Now uploading bills from T000464 to MongoDB: legislators 17 of 554
# Now uploading bills from T000250 to MongoDB: legislators 18 of 554
# Now uploading bills from S001198 to MongoDB: legislators 19 of 554
# Now uploading bills from S000770 to MongoDB: legislators 20 of 554
# Failed to upload S000770 to MongoDB
# Now uploading bills from S001227 to MongoDB: legislators 21 of 554
# Now uploading bills from S001217 to MongoDB: legislators 22 of 554
# Now uploading bills from S001203 to MongoDB: legislators 23 of 554
# Now uploading bills from S001191 to MongoDB: legislators 24 of 554
# Now uploading bills from S001184 to MongoDB: legislators 25 of 554
# Now uploading bills from S001181 to MongoDB: legislators 26 of 554
# Now uploading bills from S000148 to MongoDB: legislators 27 of 554
# Now uploading bills from S001194 to MongoDB: legislators 28 of 554
# Now uploading bills from R000595 to MongoDB: legislators 29 of 554
# Now uploading bills from S000033 to MongoDB: legislators 30 of 554
# Now uploading bills from R000615 to MongoDB: legislators 31 of 554
# Now uploading bills from R000608 to MongoDB: legislators 32 of 554
# Now uploading bills from R000605 to MongoDB: legislators 33 of 554
# Now uploading bills from R000584 to MongoDB: legislators 34 of 554
# Now uploading bills from R000618 to MongoDB: legislators 35 of 554
# Now uploading bills from P000145 to MongoDB: legislators 36 of 554
# Now uploading bills from P000603 to MongoDB: legislators 37 of 554
# Now uploading bills from P000595 to MongoDB: legislators 38 of 554
# Now uploading bills from R000122 to MongoDB: legislators 39 of 554
# Now uploading bills from O000174 to MongoDB: legislators 40 of 554
# Now uploading bills from M001169 to MongoDB: legislators 41 of 554
# Now uploading bills from M001111 to MongoDB: legislators 42 of 554
# Now uploading bills from M001190 to MongoDB: legislators 43 of 554
# Now uploading bills from M000934 to MongoDB: legislators 44 of 554
# Now uploading bills from M001153 to MongoDB: legislators 45 of 554
# Now uploading bills from M001198 to MongoDB: legislators 46 of 554
# Now uploading bills from M001183 to MongoDB: legislators 47 of 554
# Now uploading bills from L000571 to MongoDB: legislators 48 of 554
# Now uploading bills from M001176 to MongoDB: legislators 49 of 554
# Now uploading bills from M000133 to MongoDB: legislators 50 of 554
# Now uploading bills from M000355 to MongoDB: legislators 51 of 554
# Now uploading bills from K000367 to MongoDB: legislators 52 of 554
# Now uploading bills from L000577 to MongoDB: legislators 53 of 554
# Now uploading bills from L000575 to MongoDB: legislators 54 of 554
# Failed to upload L000575 to MongoDB
# Now uploading bills from L000570 to MongoDB: legislators 55 of 554
# Now uploading bills from K000377 to MongoDB: legislators 56 of 554
# Now uploading bills from K000393 to MongoDB: legislators 57 of 554
# Failed to upload K000393 to MongoDB
# Now uploading bills from K000383 to MongoDB: legislators 58 of 554
# Now uploading bills from H001097 to MongoDB: legislators 59 of 554
# Failed to upload H001097 to MongoDB
# Now uploading bills from H000273 to MongoDB: legislators 60 of 554
# Now uploading bills from H001079 to MongoDB: legislators 61 of 554
# Now uploading bills from K000384 to MongoDB: legislators 62 of 554
# Now uploading bills from J000293 to MongoDB: legislators 63 of 554
# Now uploading bills from H001061 to MongoDB: legislators 64 of 554
# Now uploading bills from H001042 to MongoDB: legislators 65 of 554
# Now uploading bills from H001089 to MongoDB: legislators 66 of 554
# Now uploading bills from H001046 to MongoDB: legislators 67 of 554
# Now uploading bills from H000601 to MongoDB: legislators 68 of 554
# Now uploading bills from H001076 to MongoDB: legislators 69 of 554
# Now uploading bills from G000386 to MongoDB: legislators 70 of 554
# Now uploading bills from F000479 to MongoDB: legislators 71 of 554
# Now uploading bills from E000295 to MongoDB: legislators 72 of 554
# Now uploading bills from F000463 to MongoDB: legislators 73 of 554
# Now uploading bills from D000622 to MongoDB: legislators 74 of 554
# Now uploading bills from G000555 to MongoDB: legislators 75 of 554
# Now uploading bills from G000359 to MongoDB: legislators 76 of 554
# Now uploading bills from D000563 to MongoDB: legislators 77 of 554
# Now uploading bills from C001098 to MongoDB: legislators 78 of 554
# Now uploading bills from D000618 to MongoDB: legislators 79 of 554
# Now uploading bills from C001096 to MongoDB: legislators 80 of 554
# Now uploading bills from C001095 to MongoDB: legislators 81 of 554
# Now uploading bills from C000880 to MongoDB: legislators 82 of 554
# Now uploading bills from C001113 to MongoDB: legislators 83 of 554
# Now uploading bills from C001070 to MongoDB: legislators 84 of 554
# Now uploading bills from C001088 to MongoDB: legislators 85 of 554
# Failed to upload C001088 to MongoDB
# Now uploading bills from C001075 to MongoDB: legislators 86 of 554
# Now uploading bills from C001035 to MongoDB: legislators 87 of 554
# Now uploading bills from C001056 to MongoDB: legislators 88 of 554
# Failed to upload C001056 to MongoDB
# Now uploading bills from C001047 to MongoDB: legislators 89 of 554
# Now uploading bills from C000174 to MongoDB: legislators 90 of 554
# Now uploading bills from C000141 to MongoDB: legislators 91 of 554
# Now uploading bills from B001320 to MongoDB: legislators 92 of 554
# Now uploading bills from B001305 to MongoDB: legislators 93 of 554
# Now uploading bills from C000127 to MongoDB: legislators 94 of 554
# Now uploading bills from B001319 to MongoDB: legislators 95 of 554
# Now uploading bills from B001310 to MongoDB: legislators 96 of 554
# Now uploading bills from B001288 to MongoDB: legislators 97 of 554
# Now uploading bills from B001277 to MongoDB: legislators 98 of 554
# Now uploading bills from B001236 to MongoDB: legislators 99 of 554
# Now uploading bills from B000944 to MongoDB: legislators 100 of 554
# Now uploading bills from B001261 to MongoDB: legislators 101 of 554
# Now uploading bills from B001267 to MongoDB: legislators 102 of 554
# Now uploading bills from B001230 to MongoDB: legislators 103 of 554
# Now uploading bills from B001243 to MongoDB: legislators 104 of 554
# Now uploading bills from L000397 to MongoDB: legislators 105 of 554
# Now uploading bills from L000604 to MongoDB: legislators 106 of 554
# Now uploading bills from M001225 to MongoDB: legislators 107 of 554
# Now uploading bills from M001229 to MongoDB: legislators 108 of 554
# Failed to upload M001229 to MongoDB
# Now uploading bills from R000599 to MongoDB: legislators 109 of 554
# Now uploading bills from D000594 to MongoDB: legislators 110 of 554
# Now uploading bills from M000639 to MongoDB: legislators 111 of 554
# Now uploading bills from P000096 to MongoDB: legislators 112 of 554
# Now uploading bills from J000032 to MongoDB: legislators 113 of 554
# Now uploading bills from P000604 to MongoDB: legislators 114 of 554
# Now uploading bills from G000579 to MongoDB: legislators 115 of 554
# Now uploading bills from K000399 to MongoDB: legislators 116 of 554
# Now uploading bills from S001159 to MongoDB: legislators 117 of 554
# Now uploading bills from C001126 to MongoDB: legislators 118 of 554
# Now uploading bills from R000619 to MongoDB: legislators 119 of 554
# Failed to upload R000619 to MongoDB
# Now uploading bills from F000480 to MongoDB: legislators 120 of 554
# Now uploading bills from K000402 to MongoDB: legislators 121 of 554
# Now uploading bills from A000380 to MongoDB: legislators 122 of 554
# Now uploading bills from B001297 to MongoDB: legislators 123 of 554
# Now uploading bills from C000537 to MongoDB: legislators 124 of 554
# Now uploading bills from F000476 to MongoDB: legislators 125 of 554
# Now uploading bills from J000292 to MongoDB: legislators 126 of 554
# Now uploading bills from M001188 to MongoDB: legislators 127 of 554
# Now uploading bills from C001132 to MongoDB: legislators 128 of 554
# Now uploading bills from C001084 to MongoDB: legislators 129 of 554
# Now uploading bills from V000135 to MongoDB: legislators 130 of 554
# Now uploading bills from G000600 to MongoDB: legislators 131 of 554
# Now uploading bills from H001096 to MongoDB: legislators 132 of 554
# Now uploading bills from B001318 to MongoDB: legislators 133 of 554
# Now uploading bills from G000595 to MongoDB: legislators 134 of 554
# Now uploading bills from F000471 to MongoDB: legislators 135 of 554
# Now uploading bills from T000165 to MongoDB: legislators 136 of 554
# Now uploading bills from M001205 to MongoDB: legislators 137 of 554
# Now uploading bills from S001213 to MongoDB: legislators 138 of 554
# Now uploading bills from S001216 to MongoDB: legislators 139 of 554
# Now uploading bills from W000825 to MongoDB: legislators 140 of 554
# Failed to upload W000825 to MongoDB
# Now uploading bills from S001209 to MongoDB: legislators 141 of 554
# Now uploading bills from C001118 to MongoDB: legislators 142 of 554
# Now uploading bills from J000298 to MongoDB: legislators 143 of 554
# Now uploading bills from M001195 to MongoDB: legislators 144 of 554
# Now uploading bills from G000576 to MongoDB: legislators 145 of 554
# Now uploading bills from N000189 to MongoDB: legislators 146 of 554
# Now uploading bills from P000610 to MongoDB: legislators 147 of 554
# Now uploading bills from B001292 to MongoDB: legislators 148 of 554
# Now uploading bills from P000607 to MongoDB: legislators 149 of 554
# Now uploading bills from K000381 to MongoDB: legislators 150 of 554
# Now uploading bills from D000617 to MongoDB: legislators 151 of 554
# Now uploading bills from G000568 to MongoDB: legislators 152 of 554
# Now uploading bills from C001078 to MongoDB: legislators 153 of 554
# Now uploading bills from S000510 to MongoDB: legislators 154 of 554
# Now uploading bills from M001160 to MongoDB: legislators 155 of 554
# Now uploading bills from M001159 to MongoDB: legislators 156 of 554
# Now uploading bills from L000560 to MongoDB: legislators 157 of 554
# Now uploading bills from M001228 to MongoDB: legislators 158 of 554
# Now uploading bills from M001227 to MongoDB: legislators 159 of 554
# Now uploading bills from S001224 to MongoDB: legislators 160 of 554
# Now uploading bills from O000175 to MongoDB: legislators 161 of 554
# Now uploading bills from M001224 to MongoDB: legislators 162 of 554
# Now uploading bills from L000603 to MongoDB: legislators 163 of 554
# Now uploading bills from H001095 to MongoDB: legislators 164 of 554
# Now uploading bills from F000478 to MongoDB: legislators 165 of 554
# Now uploading bills from C001130 to MongoDB: legislators 166 of 554
# Now uploading bills from C001131 to MongoDB: legislators 167 of 554
# Now uploading bills from E000071 to MongoDB: legislators 168 of 554
# Now uploading bills from V000134 to MongoDB: legislators 169 of 554
# Now uploading bills from P000048 to MongoDB: legislators 170 of 554
# Now uploading bills from O000086 to MongoDB: legislators 171 of 554
# Now uploading bills from N000026 to MongoDB: legislators 172 of 554
# Now uploading bills from M001213 to MongoDB: legislators 173 of 554
# Now uploading bills from M000194 to MongoDB: legislators 174 of 554
# Now uploading bills from J000304 to MongoDB: legislators 175 of 554
# Now uploading bills from H001086 to MongoDB: legislators 176 of 554
# Now uploading bills from G000594 to MongoDB: legislators 177 of 554
# Now uploading bills from F000246 to MongoDB: legislators 178 of 554
# Now uploading bills from A000376 to MongoDB: legislators 179 of 554
# Now uploading bills from G000587 to MongoDB: legislators 180 of 554
# Now uploading bills from R000614 to MongoDB: legislators 181 of 554
# Now uploading bills from E000299 to MongoDB: legislators 182 of 554
# Now uploading bills from F000468 to MongoDB: legislators 183 of 554
# Now uploading bills from G000589 to MongoDB: legislators 184 of 554
# Now uploading bills from C001120 to MongoDB: legislators 185 of 554
# Now uploading bills from G000590 to MongoDB: legislators 186 of 554
# Now uploading bills from R000612 to MongoDB: legislators 187 of 554
# Now uploading bills from B001309 to MongoDB: legislators 188 of 554
# Now uploading bills from J000301 to MongoDB: legislators 189 of 554
# Now uploading bills from T000480 to MongoDB: legislators 190 of 554
# Now uploading bills from C001115 to MongoDB: legislators 191 of 554
# Now uploading bills from C001114 to MongoDB: legislators 192 of 554
# Now uploading bills from N000190 to MongoDB: legislators 193 of 554
# Now uploading bills from A000375 to MongoDB: legislators 194 of 554
# Now uploading bills from G000581 to MongoDB: legislators 195 of 554
# Now uploading bills from K000392 to MongoDB: legislators 196 of 554
# Now uploading bills from B001291 to MongoDB: legislators 197 of 554
# Now uploading bills from V000131 to MongoDB: legislators 198 of 554
# Now uploading bills from W000816 to MongoDB: legislators 199 of 554
# Now uploading bills from C001091 to MongoDB: legislators 200 of 554
# Now uploading bills from W000814 to MongoDB: legislators 201 of 554
# Now uploading bills from W000804 to MongoDB: legislators 202 of 554
# Now uploading bills from D000616 to MongoDB: legislators 203 of 554
# Now uploading bills from F000459 to MongoDB: legislators 204 of 554
# Now uploading bills from D000615 to MongoDB: legislators 205 of 554
# Now uploading bills from C001068 to MongoDB: legislators 206 of 554
# Now uploading bills from S000250 to MongoDB: legislators 207 of 554
# Now uploading bills from G000377 to MongoDB: legislators 208 of 554
# Now uploading bills from S000185 to MongoDB: legislators 209 of 554
# Now uploading bills from C001063 to MongoDB: legislators 210 of 554
# Now uploading bills from M001157 to MongoDB: legislators 211 of 554
# Now uploading bills from G000553 to MongoDB: legislators 212 of 554
# Now uploading bills from C001051 to MongoDB: legislators 213 of 554
# Now uploading bills from B001248 to MongoDB: legislators 214 of 554
# Now uploading bills from W000795 to MongoDB: legislators 215 of 554
# Now uploading bills from D000399 to MongoDB: legislators 216 of 554
# Now uploading bills from W000828 to MongoDB: legislators 217 of 554
# Now uploading bills from S001223 to MongoDB: legislators 218 of 554
# Now uploading bills from S001226 to MongoDB: legislators 219 of 554
# Failed to upload S001226 to MongoDB
# Now uploading bills from M001221 to MongoDB: legislators 220 of 554
# Now uploading bills from M001222 to MongoDB: legislators 221 of 554
# Now uploading bills from M001223 to MongoDB: legislators 222 of 554
# Now uploading bills from L000602 to MongoDB: legislators 223 of 554
# Now uploading bills from L000599 to MongoDB: legislators 224 of 554
# Now uploading bills from L000600 to MongoDB: legislators 225 of 554
# Now uploading bills from L000601 to MongoDB: legislators 226 of 554
# Now uploading bills from H001094 to MongoDB: legislators 227 of 554
# Now uploading bills from D000530 to MongoDB: legislators 228 of 554
# Now uploading bills from C001135 to MongoDB: legislators 229 of 554
# Now uploading bills from B001317 to MongoDB: legislators 230 of 554
# Now uploading bills from R000579 to MongoDB: legislators 231 of 554
# Now uploading bills from B001313 to MongoDB: legislators 232 of 554
# Now uploading bills from B001223 to MongoDB: legislators 233 of 554
# Now uploading bills from B000740 to MongoDB: legislators 234 of 554
# Now uploading bills from B000668 to MongoDB: legislators 235 of 554
# Now uploading bills from R000610 to MongoDB: legislators 236 of 554
# Now uploading bills from J000302 to MongoDB: legislators 237 of 554
# Now uploading bills from M001204 to MongoDB: legislators 238 of 554
# Now uploading bills from H001085 to MongoDB: legislators 239 of 554
# Now uploading bills from D000631 to MongoDB: legislators 240 of 554
# Now uploading bills from W000826 to MongoDB: legislators 241 of 554
# Now uploading bills from H001082 to MongoDB: legislators 242 of 554
# Now uploading bills from M001206 to MongoDB: legislators 243 of 554
# Now uploading bills from S001205 to MongoDB: legislators 244 of 554
# Now uploading bills from B001306 to MongoDB: legislators 245 of 554
# Now uploading bills from G000582 to MongoDB: legislators 246 of 554
# Now uploading bills from S001199 to MongoDB: legislators 247 of 554
# Now uploading bills from F000466 to MongoDB: legislators 248 of 554
# Now uploading bills from T000478 to MongoDB: legislators 249 of 554
# Now uploading bills from E000296 to MongoDB: legislators 250 of 554
# Now uploading bills from D000626 to MongoDB: legislators 251 of 554
# Now uploading bills from B001296 to MongoDB: legislators 252 of 554
# Now uploading bills from S001196 to MongoDB: legislators 253 of 554
# Now uploading bills from C001090 to MongoDB: legislators 254 of 554
# Now uploading bills from P000605 to MongoDB: legislators 255 of 554
# Now uploading bills from J000295 to MongoDB: legislators 256 of 554
# Now uploading bills from B001281 to MongoDB: legislators 257 of 554
# Now uploading bills from W000815 to MongoDB: legislators 258 of 554
# Now uploading bills from B001278 to MongoDB: legislators 259 of 554
# Now uploading bills from L000566 to MongoDB: legislators 260 of 554
# Now uploading bills from K000376 to MongoDB: legislators 261 of 554
# Now uploading bills from J000289 to MongoDB: legislators 262 of 554
# Now uploading bills from T000467 to MongoDB: legislators 263 of 554
# Now uploading bills from T000469 to MongoDB: legislators 264 of 554
# Now uploading bills from B000574 to MongoDB: legislators 265 of 554
# Now uploading bills from L000491 to MongoDB: legislators 266 of 554
# Now uploading bills from C001053 to MongoDB: legislators 267 of 554
# Now uploading bills from T000463 to MongoDB: legislators 268 of 554
# Now uploading bills from K000009 to MongoDB: legislators 269 of 554
# Now uploading bills from V000136 to MongoDB: legislators 270 of 554
# Now uploading bills from N000194 to MongoDB: legislators 271 of 554
# Now uploading bills from M001226 to MongoDB: legislators 272 of 554
# Now uploading bills from L000598 to MongoDB: legislators 273 of 554
# Now uploading bills from K000398 to MongoDB: legislators 274 of 554
# Now uploading bills from J000308 to MongoDB: legislators 275 of 554
# Now uploading bills from G000599 to MongoDB: legislators 276 of 554
# Now uploading bills from E000246 to MongoDB: legislators 277 of 554
# Now uploading bills from D000632 to MongoDB: legislators 278 of 554
# Now uploading bills from F000474 to MongoDB: legislators 279 of 554
# Now uploading bills from S001218 to MongoDB: legislators 280 of 554
# Now uploading bills from T000486 to MongoDB: legislators 281 of 554
# Now uploading bills from M001135 to MongoDB: legislators 282 of 554
# Now uploading bills from M000317 to MongoDB: legislators 283 of 554
# Now uploading bills from L000273 to MongoDB: legislators 284 of 554
# Now uploading bills from G000597 to MongoDB: legislators 285 of 554
# Now uploading bills from B001311 to MongoDB: legislators 286 of 554
# Now uploading bills from O000172 to MongoDB: legislators 287 of 554
# Now uploading bills from L000590 to MongoDB: legislators 288 of 554
# Now uploading bills from S001207 to MongoDB: legislators 289 of 554
# Now uploading bills from K000394 to MongoDB: legislators 290 of 554
# Now uploading bills from V000133 to MongoDB: legislators 291 of 554
# Now uploading bills from P000614 to MongoDB: legislators 292 of 554
# Now uploading bills from A000377 to MongoDB: legislators 293 of 554
# Now uploading bills from E000297 to MongoDB: legislators 294 of 554
# Now uploading bills from S001201 to MongoDB: legislators 295 of 554
# Now uploading bills from G000583 to MongoDB: legislators 296 of 554
# Now uploading bills from B001298 to MongoDB: legislators 297 of 554
# Now uploading bills from W000822 to MongoDB: legislators 298 of 554
# Now uploading bills from R000603 to MongoDB: legislators 299 of 554
# Now uploading bills from A000370 to MongoDB: legislators 300 of 554
# Now uploading bills from J000294 to MongoDB: legislators 301 of 554
# Failed to upload J000294 to MongoDB
# Now uploading bills from H001066 to MongoDB: legislators 302 of 554
# Now uploading bills from K000382 to MongoDB: legislators 303 of 554
# Now uploading bills from H001067 to MongoDB: legislators 304 of 554
# Now uploading bills from A000369 to MongoDB: legislators 305 of 554
# Now uploading bills from C001067 to MongoDB: legislators 306 of 554
# Now uploading bills from S001172 to MongoDB: legislators 307 of 554
# Now uploading bills from T000468 to MongoDB: legislators 308 of 554
# Now uploading bills from P000034 to MongoDB: legislators 309 of 554
# Now uploading bills from M001137 to MongoDB: legislators 310 of 554
# Now uploading bills from V000081 to MongoDB: legislators 311 of 554
# Now uploading bills from S000522 to MongoDB: legislators 312 of 554
# Now uploading bills from N000002 to MongoDB: legislators 313 of 554
# Now uploading bills from M001156 to MongoDB: legislators 314 of 554
# Now uploading bills from F000450 to MongoDB: legislators 315 of 554
# Now uploading bills from T000488 to MongoDB: legislators 316 of 554
# Now uploading bills from S001221 to MongoDB: legislators 317 of 554
# Now uploading bills from J000307 to MongoDB: legislators 318 of 554
# Now uploading bills from I000058 to MongoDB: legislators 319 of 554
# Now uploading bills from F000477 to MongoDB: legislators 320 of 554
# Now uploading bills from E000235 to MongoDB: legislators 321 of 554
# Now uploading bills from D000230 to MongoDB: legislators 322 of 554
# Now uploading bills from B001316 to MongoDB: legislators 323 of 554
# Now uploading bills from A000379 to MongoDB: legislators 324 of 554
# Now uploading bills from F000475 to MongoDB: legislators 325 of 554
# Now uploading bills from R000305 to MongoDB: legislators 326 of 554
# Now uploading bills from R000103 to MongoDB: legislators 327 of 554
# Now uploading bills from M001136 to MongoDB: legislators 328 of 554
# Now uploading bills from F000470 to MongoDB: legislators 329 of 554
# Now uploading bills from B001224 to MongoDB: legislators 330 of 554
# Now uploading bills from A000148 to MongoDB: legislators 331 of 554
# Now uploading bills from M001210 to MongoDB: legislators 332 of 554
# Now uploading bills from G000592 to MongoDB: legislators 333 of 554
# Now uploading bills from G000591 to MongoDB: legislators 334 of 554
# Now uploading bills from S001212 to MongoDB: legislators 335 of 554
# Now uploading bills from O000173 to MongoDB: legislators 336 of 554
# Now uploading bills from P000616 to MongoDB: legislators 337 of 554
# Now uploading bills from C001119 to MongoDB: legislators 338 of 554
# Now uploading bills from T000481 to MongoDB: legislators 339 of 554
# Now uploading bills from S001215 to MongoDB: legislators 340 of 554
# Now uploading bills from S001208 to MongoDB: legislators 341 of 554
# Now uploading bills from T000483 to MongoDB: legislators 342 of 554
# Now uploading bills from P000617 to MongoDB: legislators 343 of 554
# Now uploading bills from T000482 to MongoDB: legislators 344 of 554
# Now uploading bills from B001301 to MongoDB: legislators 345 of 554
# Now uploading bills from R000606 to MongoDB: legislators 346 of 554
# Now uploading bills from K000388 to MongoDB: legislators 347 of 554
# Now uploading bills from Z000018 to MongoDB: legislators 348 of 554
# Now uploading bills from E000294 to MongoDB: legislators 349 of 554
# Now uploading bills from D000624 to MongoDB: legislators 350 of 554
# Failed to upload D000624 to MongoDB
# Now uploading bills from M001194 to MongoDB: legislators 351 of 554
# Now uploading bills from M001196 to MongoDB: legislators 352 of 554
# Now uploading bills from C001101 to MongoDB: legislators 353 of 554
# Now uploading bills from W000812 to MongoDB: legislators 354 of 554
# Now uploading bills from K000380 to MongoDB: legislators 355 of 554
# Now uploading bills from S001195 to MongoDB: legislators 356 of 554
# Now uploading bills from H001058 to MongoDB: legislators 357 of 554
# Now uploading bills from H001052 to MongoDB: legislators 358 of 554
# Now uploading bills from K000375 to MongoDB: legislators 359 of 554
# Now uploading bills from S001177 to MongoDB: legislators 360 of 554
# Now uploading bills from W000798 to MongoDB: legislators 361 of 554
# Now uploading bills from S001168 to MongoDB: legislators 362 of 554
# Now uploading bills from L000569 to MongoDB: legislators 363 of 554
# Now uploading bills from P000597 to MongoDB: legislators 364 of 554
# Now uploading bills from M000312 to MongoDB: legislators 365 of 554
# Now uploading bills from T000193 to MongoDB: legislators 366 of 554
# Now uploading bills from N000015 to MongoDB: legislators 367 of 554
# Now uploading bills from M000687 to MongoDB: legislators 368 of 554
# Now uploading bills from C001061 to MongoDB: legislators 369 of 554
# Now uploading bills from R000576 to MongoDB: legislators 370 of 554
# Now uploading bills from L000562 to MongoDB: legislators 371 of 554
# Now uploading bills from G000546 to MongoDB: legislators 372 of 554
# Now uploading bills from M001143 to MongoDB: legislators 373 of 554
# Now uploading bills from H000874 to MongoDB: legislators 374 of 554
# Now uploading bills from T000487 to MongoDB: legislators 375 of 554
# Now uploading bills from S001225 to MongoDB: legislators 376 of 554
# Now uploading bills from R000617 to MongoDB: legislators 377 of 554
# Now uploading bills from N000193 to MongoDB: legislators 378 of 554
# Failed to upload N000193 to MongoDB
# Now uploading bills from M001219 to MongoDB: legislators 379 of 554
# Now uploading bills from M001220 to MongoDB: legislators 380 of 554
# Now uploading bills from M001218 to MongoDB: legislators 381 of 554
# Now uploading bills from J000309 to MongoDB: legislators 382 of 554
# Failed to upload J000309 to MongoDB
# Now uploading bills from H001093 to MongoDB: legislators 383 of 554
# Now uploading bills from C001129 to MongoDB: legislators 384 of 554
# Now uploading bills from B001315 to MongoDB: legislators 385 of 554
# Now uploading bills from Y000067 to MongoDB: legislators 386 of 554
# Now uploading bills from C001125 to MongoDB: legislators 387 of 554
# Now uploading bills from L000595 to MongoDB: legislators 388 of 554
# Now uploading bills from S000929 to MongoDB: legislators 389 of 554
# Now uploading bills from M001215 to MongoDB: legislators 390 of 554
# Now uploading bills from M001214 to MongoDB: legislators 391 of 554
# Now uploading bills from M001211 to MongoDB: legislators 392 of 554
# Now uploading bills from M000871 to MongoDB: legislators 393 of 554
# Now uploading bills from L000266 to MongoDB: legislators 394 of 554
# Now uploading bills from H001091 to MongoDB: legislators 395 of 554
# Now uploading bills from G000596 to MongoDB: legislators 396 of 554
# Now uploading bills from F000446 to MongoDB: legislators 397 of 554
# Now uploading bills from C001116 to MongoDB: legislators 398 of 554
# Now uploading bills from D000629 to MongoDB: legislators 399 of 554
# Now uploading bills from P000615 to MongoDB: legislators 400 of 554
# Now uploading bills from B001307 to MongoDB: legislators 401 of 554
# Now uploading bills from U000040 to MongoDB: legislators 402 of 554
# Now uploading bills from C001117 to MongoDB: legislators 403 of 554
# Now uploading bills from G000586 to MongoDB: legislators 404 of 554
# Now uploading bills from F000469 to MongoDB: legislators 405 of 554
# Now uploading bills from M001208 to MongoDB: legislators 406 of 554
# Now uploading bills from E000298 to MongoDB: legislators 407 of 554
# Now uploading bills from J000299 to MongoDB: legislators 408 of 554
# Now uploading bills from H001077 to MongoDB: legislators 409 of 554
# Now uploading bills from B001299 to MongoDB: legislators 410 of 554
# Now uploading bills from K000391 to MongoDB: legislators 411 of 554
# Now uploading bills from C001108 to MongoDB: legislators 412 of 554
# Now uploading bills from L000585 to MongoDB: legislators 413 of 554
# Now uploading bills from G000577 to MongoDB: legislators 414 of 554
# Now uploading bills from B001295 to MongoDB: legislators 415 of 554
# Now uploading bills from A000372 to MongoDB: legislators 416 of 554
# Now uploading bills from L000583 to MongoDB: legislators 417 of 554
# Now uploading bills from B001282 to MongoDB: legislators 418 of 554
# Now uploading bills from S001190 to MongoDB: legislators 419 of 554
# Failed to upload S001190 to MongoDB
# Now uploading bills from M001184 to MongoDB: legislators 420 of 554
# Now uploading bills from B001275 to MongoDB: legislators 421 of 554
# Now uploading bills from S001189 to MongoDB: legislators 422 of 554
# Now uploading bills from Q000023 to MongoDB: legislators 423 of 554
# Now uploading bills from G000558 to MongoDB: legislators 424 of 554
# Now uploading bills from S001176 to MongoDB: legislators 425 of 554
# Now uploading bills from F000454 to MongoDB: legislators 426 of 554
# Now uploading bills from C001072 to MongoDB: legislators 427 of 554
# Now uploading bills from K000385 to MongoDB: legislators 428 of 554
# Now uploading bills from S001148 to MongoDB: legislators 429 of 554
# Now uploading bills from S001145 to MongoDB: legislators 430 of 554
# Now uploading bills from D000096 to MongoDB: legislators 431 of 554
# Now uploading bills from R000395 to MongoDB: legislators 432 of 554
# Now uploading bills from S001157 to MongoDB: legislators 433 of 554
# Now uploading bills from C001055 to MongoDB: legislators 434 of 554
# Now uploading bills from P000620 to MongoDB: legislators 435 of 554
# Now uploading bills from M001217 to MongoDB: legislators 436 of 554
# Now uploading bills from M001216 to MongoDB: legislators 437 of 554
# Now uploading bills from L000596 to MongoDB: legislators 438 of 554
# Now uploading bills from L000597 to MongoDB: legislators 439 of 554
# Now uploading bills from G000598 to MongoDB: legislators 440 of 554
# Now uploading bills from C001134 to MongoDB: legislators 441 of 554
# Now uploading bills from B001314 to MongoDB: legislators 442 of 554
# Now uploading bills from C001127 to MongoDB: legislators 443 of 554
# Now uploading bills from K000397 to MongoDB: legislators 444 of 554
# Now uploading bills from W000788 to MongoDB: legislators 445 of 554
# Now uploading bills from S001135 to MongoDB: legislators 446 of 554
# Now uploading bills from S000168 to MongoDB: legislators 447 of 554
# Now uploading bills from J000305 to MongoDB: legislators 448 of 554
# Now uploading bills from G000593 to MongoDB: legislators 449 of 554
# Now uploading bills from F000472 to MongoDB: legislators 450 of 554
# Now uploading bills from D000032 to MongoDB: legislators 451 of 554
# Now uploading bills from C001039 to MongoDB: legislators 452 of 554
# Now uploading bills from B000825 to MongoDB: legislators 453 of 554
# Now uploading bills from S001214 to MongoDB: legislators 454 of 554
# Now uploading bills from W000823 to MongoDB: legislators 455 of 554
# Now uploading bills from H001081 to MongoDB: legislators 456 of 554
# Now uploading bills from C001121 to MongoDB: legislators 457 of 554
# Now uploading bills from N000191 to MongoDB: legislators 458 of 554
# Now uploading bills from L000593 to MongoDB: legislators 459 of 554
# Now uploading bills from P000618 to MongoDB: legislators 460 of 554
# Failed to upload P000618 to MongoDB
# Now uploading bills from F000465 to MongoDB: legislators 461 of 554
# Now uploading bills from M001199 to MongoDB: legislators 462 of 554
# Now uploading bills from S001200 to MongoDB: legislators 463 of 554
# Now uploading bills from R000609 to MongoDB: legislators 464 of 554
# Now uploading bills from D000628 to MongoDB: legislators 465 of 554
# Now uploading bills from B001303 to MongoDB: legislators 466 of 554
# Now uploading bills from C001110 to MongoDB: legislators 467 of 554
# Now uploading bills from B001300 to MongoDB: legislators 468 of 554
# Now uploading bills from C001103 to MongoDB: legislators 469 of 554
# Now uploading bills from F000462 to MongoDB: legislators 470 of 554
# Now uploading bills from P000608 to MongoDB: legislators 471 of 554
# Now uploading bills from V000130 to MongoDB: legislators 472 of 554
# Now uploading bills from T000472 to MongoDB: legislators 473 of 554
# /Users/oliverchen/.pyenv/versions/3.12.5/lib/python3.12/html/parser.py:171: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
# Now uploading bills from W000808 to MongoDB: legislators 474 of 554
# Now uploading bills from W000806 to MongoDB: legislators 475 of 554
# Now uploading bills from J000288 to MongoDB: legislators 476 of 554
# Now uploading bills from B001260 to MongoDB: legislators 477 of 554
# Now uploading bills from C001066 to MongoDB: legislators 478 of 554
# Now uploading bills from B001257 to MongoDB: legislators 479 of 554
# Now uploading bills from C001069 to MongoDB: legislators 480 of 554
# Now uploading bills from L000564 to MongoDB: legislators 481 of 554
# Now uploading bills from P000599 to MongoDB: legislators 482 of 554
# Now uploading bills from H001047 to MongoDB: legislators 483 of 554
# Now uploading bills from L000557 to MongoDB: legislators 484 of 554
# Now uploading bills from D000197 to MongoDB: legislators 485 of 554
# Now uploading bills from W000187 to MongoDB: legislators 486 of 554
# Now uploading bills from B000490 to MongoDB: legislators 487 of 554
# Now uploading bills from N000147 to MongoDB: legislators 488 of 554
# Now uploading bills from W000797 to MongoDB: legislators 489 of 554
# Now uploading bills from D000600 to MongoDB: legislators 490 of 554
# Now uploading bills from I000056 to MongoDB: legislators 491 of 554
# Now uploading bills from C000059 to MongoDB: legislators 492 of 554
# Now uploading bills from D000216 to MongoDB: legislators 493 of 554
# Now uploading bills from K000401 to MongoDB: legislators 494 of 554
# Now uploading bills from K000400 to MongoDB: legislators 495 of 554
# Failed to upload K000400 to MongoDB
# Now uploading bills from D000633 to MongoDB: legislators 496 of 554
# Now uploading bills from C001133 to MongoDB: legislators 497 of 554
# Now uploading bills from O000019 to MongoDB: legislators 498 of 554
# Now uploading bills from G000061 to MongoDB: legislators 499 of 554
# Now uploading bills from H001090 to MongoDB: legislators 500 of 554
# Now uploading bills from S001211 to MongoDB: legislators 501 of 554
# Now uploading bills from L000589 to MongoDB: legislators 502 of 554
# Now uploading bills from G000585 to MongoDB: legislators 503 of 554
# Now uploading bills from C001112 to MongoDB: legislators 504 of 554
# Now uploading bills from B001302 to MongoDB: legislators 505 of 554
# Now uploading bills from P000613 to MongoDB: legislators 506 of 554
# Now uploading bills from K000389 to MongoDB: legislators 507 of 554
# Failed to upload K000389 to MongoDB
# Now uploading bills from T000474 to MongoDB: legislators 508 of 554
# Now uploading bills from L000582 to MongoDB: legislators 509 of 554
# Now uploading bills from A000371 to MongoDB: legislators 510 of 554
# Now uploading bills from D000623 to MongoDB: legislators 511 of 554
# Now uploading bills from G000574 to MongoDB: legislators 512 of 554
# Now uploading bills from W000821 to MongoDB: legislators 513 of 554
# Now uploading bills from R000600 to MongoDB: legislators 514 of 554
# Now uploading bills from C001097 to MongoDB: legislators 515 of 554
# Now uploading bills from B001285 to MongoDB: legislators 516 of 554
# Now uploading bills from V000129 to MongoDB: legislators 517 of 554
# Now uploading bills from S001193 to MongoDB: legislators 518 of 554
# Now uploading bills from B001287 to MongoDB: legislators 519 of 554
# Now uploading bills from H001068 to MongoDB: legislators 520 of 554
# Now uploading bills from L000578 to MongoDB: legislators 521 of 554
# Now uploading bills from G000559 to MongoDB: legislators 522 of 554
# Now uploading bills from C001080 to MongoDB: legislators 523 of 554
# Now uploading bills from S001183 to MongoDB: legislators 524 of 554
# Now uploading bills from G000565 to MongoDB: legislators 525 of 554
# Now uploading bills from M001177 to MongoDB: legislators 526 of 554
# Now uploading bills from M001163 to MongoDB: legislators 527 of 554
# Now uploading bills from P000197 to MongoDB: legislators 528 of 554
# Now uploading bills from N000179 to MongoDB: legislators 529 of 554
# Now uploading bills from T000460 to MongoDB: legislators 530 of 554
# Now uploading bills from S000344 to MongoDB: legislators 531 of 554
# Now uploading bills from L000551 to MongoDB: legislators 532 of 554
# Failed to upload L000551 to MongoDB
# Now uploading bills from C001059 to MongoDB: legislators 533 of 554
# Now uploading bills from G000551 to MongoDB: legislators 534 of 554
# Now uploading bills from S001156 to MongoDB: legislators 535 of 554
# Now uploading bills from S001150 to MongoDB: legislators 536 of 554
# Now uploading bills from E000215 to MongoDB: legislators 537 of 554
# Now uploading bills from S001220 to MongoDB: legislators 538 of 554
# Now uploading bills from P000619 to MongoDB: legislators 539 of 554
# Now uploading bills from C001054 to MongoDB: legislators 540 of 554
# Now uploading bills from M001212 to MongoDB: legislators 541 of 554
# Now uploading bills from H001072 to MongoDB: legislators 542 of 554
# Failed to upload H001072 to MongoDB
# Now uploading bills from P000609 to MongoDB: legislators 543 of 554
# Now uploading bills from W000809 to MongoDB: legislators 544 of 554
# Now uploading bills from C001087 to MongoDB: legislators 545 of 554
# Now uploading bills from S001185 to MongoDB: legislators 546 of 554
# Now uploading bills from A000055 to MongoDB: legislators 547 of 554
# Now uploading bills from R000575 to MongoDB: legislators 548 of 554
# Now uploading bills from M001165 to MongoDB: legislators 549 of 554
# Failed to upload M001165 to MongoDB
# Now uploading bills from H001038 to MongoDB: legislators 550 of 554
# Now uploading bills from S001222 to MongoDB: legislators 551 of 554
# Now uploading bills from S001192 to MongoDB: legislators 552 of 554
# Now uploading bills from F000062 to MongoDB: legislators 553 of 554
# Now uploading bills from S001197 to MongoDB: legislators 554 of 554
# Failed to upload S001197 to MongoDB
